# %% [markdown]
# 1.What does an empty dictionary's code look like?
# An empty dictionary is often represented by two empty curly brackets

# %% [markdown]
# 2.what is the value of dictionary value with key 'foo' and the value 42 ?
# {'foo':42}`

# %% [markdown]
# 3.What is the most significant distinction between a dictionary and a list?
# Dictionaries are represented by `{}` where as listed are represented by `[]`
# The Items stored in a dictionary are Unordered , while the items in a list are ordered

# %% [markdown]
# 4.What happens if you try to access spam ['foo'] if spam is {'bar':100} ?
# we will get a keyError `KeyError: 'foo'`

# %% [markdown]
# 5.if a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys() ?
# There is no difference . The operator checks whether a value exits as a key in the dictionary or not

# %% [markdown]
# 6.if a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.values() ?
# 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# 7.what is a shortcut for the following code ?
# `if 'color' not in spam:
#     spam['color'] ='black'`
#
#  spam.setdefault('color','black')

# %% [markdown]
# 8.How do you 'pretty print' dictionary values using which modules and function ?
# we can pretty print a dictionary using three functions
# 1. by using print() function of pprint module
# 2. by using pprint method.

# %%
n= [
  {'Name': 'Manu', 'Age': '30', 'Residence': {'City': 'Gwalior'}},
  {'Name': 'Rahot', 'Age': '30', 'Residence': {'City': 'Gwalior'}},
]

# %%
#1. by using print() function of pprint module
print(n)
# Out:
# [{'Name': 'Manu', 'Age': '30', 'Residence': {'City': 'Gwalior'}}, {'Name': 'Rahot', 'Age': '30', 'Residence': {'City': 'Gwalior'}}]

# %%
#2. by using pprint() function of pprint module
import pprint
print('Printing using pprint() funciton')
pprint.pprint(n)
# Out:
# Printing using pprint() funciton
# [{'Age': '30', 'Name': 'Manu', 'Residence': {'City': 'Gwalior'}},
#  {'Age': '30', 'Name': 'Rahot', 'Residence': {'City': 'Gwalior'}}]
