# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *          ==  expressions
# 'hello'    ==  values
# -87.8      ==  values
# -          ==  expression
# /          ==  expression
# +          ==  expression
# 6          ==  values

# %% [markdown]
# 2. What is the difference between string and variable?
#
# String ==  String is a text.
# Variables == Variables are the name of values.

# %% [markdown]
# 3. Describe three different data types.
#
# 1.Set = Set is a collection of non common elements.
# 2.Numeric = Numeric are the data types in which number is values
# 3.String = String is a data type of text.

# %% [markdown]
# What is an expression made up of? What do all expressions do?
#
# Expression is made up of various things like operators , with the help of expressionin  we compare things with each other.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# With the help of expression we conclude something which one is correct while statement is print statement like print("hello") in which hello is statement.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# spamspamspam
#
#
# 'spam' * 3
# spamspamspam

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Eggs is valid because variable name can not start from number.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# integer = int()
# floating-point number = float()
# string = str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# because 99 is numberic. To solve this we have to convert it into string.
